# %%
import requests

urls = [
    "https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz",
    "https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz"
]

for url in urls:
    filename = url.split("/")[-1]
    print(f"Downloading {filename} ...")
    response = requests.get(url)
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"{filename} downloaded!")
# Out:
# ...
# SQuAD_it-train.json.gz downloaded!
# ...
# SQuAD_it-test.json.gz downloaded!

# %%
# !gzip -dkv SQuAD_it-*.json.gz
# Out:
# SQuAD_it-test.json.gz:	   87.4% -- replaced with SQuAD_it-test.json
# SQuAD_it-train.json.gz:	   82.2% -- replaced with SQuAD_it-train.json

# %%
from datasets import load_dataset

squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"][0]
# Out:
# {'title': 'Terremoto del Sichuan del 2008',
#  'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %% [markdown]
# # Slicing and Dicing the dataset

# %%
from datasets import load_dataset

data_files= {"train": "drugsComTrain_raw.tsv", "test": "drugsComTest_raw.tsv"}

drug_dataset = load_dataset("csv", data_files= data_files, delimiter ="\t")

# %%
drug_dataset["train"][:3]
# Out:
# {'Unnamed: 0': [206461, 95260, 92703],
#  'drugName': ['Valsartan', 'Guanfacine', 'Lybrel'],
#  'condition': ['Left Ventricular Dysfunction', 'ADHD', 'Birth Control'],
#  'review': ['"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
# ...

# %%
drug_sample= drug_dataset["train"].shuffle(seed=42).select(range(1000))

drug_sample[:3]
# Out:
# {'Unnamed: 0': [87571, 178045, 80482],
#  'drugName': ['Naproxen', 'Duloxetine', 'Mobic'],
#  'condition': ['Gout, Acute', 'ibromyalgia', 'Inflammatory Conditions'],
#  'review': ['"like the previous person mention, I&#039;m a strong believer of aleve, it works faster for my gout than the prescription meds I take. No more going to the doctor for refills.....Aleve works!"',
#   '"I have taken Cymbalta for about a year and a half for fibromyalgia pain. It is great\r\nas a pain reducer and an anti-depressant, however, the side effects outweighed \r\nany benefit I got from it. I had trouble with restlessness, being tired constantly,\r\ndizziness, dry mouth, numbness and tingling in my feet, and horrible sweating. I am\r\nbeing weaned off of it now. Went from 60 mg to 30mg and now to 15 mg. I will be\r\noff completely in about a week. The fibro pain is coming back, but I would rather deal with it than the side effects."',
# ...

# %%
for split in drug_dataset.keys():
    assert len(drug_dataset[split]) == len(drug_dataset[split].unique("Unnamed: 0"))

# %%
drug_dataset = drug_dataset.rename_column(
    original_column_name="Unnamed: 0", new_column_name="patient_id"
)
drug_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 161297
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53766
#     })
# })

# %%
drug_dataset["train"].unique("drugName")
drug_dataset["test"].unique("drugName")
# Out:
# ['Mirtazapine',
#  'Mesalamine',
#  'Bactrim',
#  'Contrave',
#  'Cyclafem 1 / 35',
#  'Zyclara',
#  'Copper',
#  'Amitriptyline',
#  'Methadone',
#  'Levora',
#  'Paroxetine',
#  'Miconazole',
#  'Belviq',
#  'Seroquel',
#  'Ambien',
#  'Nuvigil',
#  'Chantix',
#  'Microgestin Fe 1 / 20',
#  'Klonopin',
#  'Ciprofloxacin',
#  'Trazodone',
#  'EnteraGam',
#  'Aripiprazole',
#  'Cyclosporine',
#  'Oxybutynin',
#  'Lurasidone',
#  'Clonazepam',
#  'Ciclopirox',
#  'Sodium oxybate',
#  'Lamotrigine',
#  'Blisovi Fe 1 / 20',
#  'Ivermectin',
#  'Suprep Bowel Prep Kit',
#  'Movantik',
#  'Lorcaserin',
#  'Actos',
#  'Duloxetine',
#  'NuvaRing',
#  'Escitalopram',
#  'Tesamorelin',
#  'Campral',
#  'Gabapentin',
#  'Levonorgestrel',
#  'Aubra',
#  'Plan B One-Step',
#  'Ethinyl estradiol / etonogestrel',
#  'Microgestin Fe 1.5 / 30',
#  'Wellbutrin',
#  'Benzoyl peroxide / clindamycin',
#  'Etonogestrel',
#  'Nitrofurantoin',
#  'Ortho Tri-Cyclen Lo',
#  'Tamsulosin',
#  'Tofacitinib',
# ...

# %%
num_unique_train = len(drug_dataset["train"].unique("drugName"))

num_unique_test = len(drug_dataset["test"].unique("drugName"))

print(num_unique_train)
print(num_unique_test)
# Out:
# 3436
# 2637

# %%
def lowercase_condition(example):
    return {"condition": example["condition"].lower()}

drug_dataset=drug_dataset.filter(lambda x: x["condition"] is not None)

drug_dataset= drug_dataset.map(lowercase_condition)

# %%
drug_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 160398
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53471
#     })
# })

# %%
drug_dataset["train"]["condition"][:3]
# Out:
# ['left ventricular dysfunction', 'adhd', 'birth control']

# %%
def compute_review_length(example):
    return  {"review_length": len(example["review"].split()) }

# %%
drug_dataset=drug_dataset.map(compute_review_length)

# %%
drug_dataset["train"][:3]
# Out:
# {'patient_id': [206461, 95260, 92703],
#  'drugName': ['Valsartan', 'Guanfacine', 'Lybrel'],
#  'condition': ['left ventricular dysfunction', 'adhd', 'birth control'],
#  'review': ['"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
# ...

# %%
drug_dataset["train"].sort("review_length")[:3]
# Out:
# {'patient_id': [111469, 13653, 53602],
#  'drugName': ['Ledipasvir / sofosbuvir',
#   'Amphetamine / dextroamphetamine',
#   'Alesse'],
#  'condition': ['hepatitis c', 'adhd', 'birth control'],
#  'review': ['"Headache"', '"Great"', '"Awesome"'],
#  'rating': [10.0, 10.0, 10.0],
#  'date': ['February 3, 2015', 'October 20, 2009', 'November 23, 2015'],
#  'usefulCount': [41, 3, 0],
#  'review_length': [1, 1, 1]}

# %%
print(drug_dataset.num_rows)
# Out:
# {'train': 160398, 'test': 53471}

# %%
def filter_review_length(example):
    return example["review_length"]>30

# %%
drug_dataset= drug_dataset.filter(filter_review_length)
# Out:
# ...
# Filter:   0%|          | 0/53471 [00:00<?, ? examples/s]

# %%
print(drug_dataset.num_rows)
# Out:
# {'train': 138514, 'test': 46108}

# %%
drug_dataset["train"].sort("review_length")[:3]
# Out:
# {'patient_id': [208641, 118552, 2448],
#  'drugName': ['Amlodipine / olmesartan',
#   'Amoxicillin / clarithromycin / lansoprazole',
#   'Emend'],
#  'condition': ['high blood pressure',
#   'helicobacter pylori infection',
#   'nausea/vomiting, postoperative'],
#  'review': ['"My blood pressure has been around 160/100. Doctor prescribed Azor 40/10. Just 4 hrs later my reading showed 120/82. I was amazed. I am now on it daily. Thanks to Azor."',
#   '"I had severe vomiting and diarhoea for 3 days caused by clarythromycin. After being treated for dehydration at the hospital, clarythormycin was replaced with doxycycline, and I have no problems since."',
#   '"I always get nausea and vomiting with anesthesia even when taking other anti-nausea meds. Was given Emend prior to gallbladder removal. Woke up with absolutely no nausea. Worked great for me!"'],
#  'rating': [10.0, 2.0, 10.0],
#  'date': ['January 19, 2015', 'February 18, 2017', 'August 3, 2016'],
#  'usefulCount': [10, 4, 1],
# ...

# %%
drug_dataset["train"].sort("review_length", reverse=True)[:3]
# Out:
# {'patient_id': [121004, 181160, 216072],
#  'drugName': ['Venlafaxine', 'Prozac', 'Copper'],
#  'condition': ['migraine', 'obsessive compulsive disorde', 'birth control'],
# ...

# %%
import html

text = "I&#039;m a transformer called BERT"
html.unescape(text)
# Out:
# "I'm a transformer called BERT"

# %%
drug_dataset= drug_dataset.map(lambda x:{"review": html.unescape(x["review"])})
# Out:
# ...
# Map:   0%|          | 0/46108 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def tokenize_function(examples):
    return tokenizer(examples["review"], truncation = True)

# %%
# %time tokenized_dataset= drug_dataset.map(tokenize_function, batched = True)
# Out:
# ...
# Map:   0%|          | 0/46108 [00:00<?, ? examples/s]
# CPU times: user 43.2 s, sys: 800 ms, total: 44 s
# Wall time: 11.2 s

# %%
# %time tokenized_dataset= drug_dataset.map(tokenize_function)
# Out:
# ...
# Map:   0%|          | 0/46108 [00:00<?, ? examples/s]
# CPU times: user 37.5 s, sys: 407 ms, total: 37.9 s
# Wall time: 37.9 s

# %%
def tokenize_and_split(examples):
    return tokenizer(
        examples["review"],
        truncation=True,
        max_length=128,
        return_overflowing_tokens=True,
    )

# %%
result = tokenize_and_split(drug_dataset["train"][0])
[len(inp) for inp in result["input_ids"]]
# Out:
# [128, 49]

# %%
#tokenized_dataset = drug_dataset.map(tokenize_and_split,batched = True)

# %%
len(drug_dataset["train"])
# Out:
# 138514

# %%
drug_dataset["train"][0]["review"]
# Out:
# '"My son is halfway through his fourth week of Intuniv. We became concerned when he began this last week, when he started taking the highest dose he will be on. For two days, he could hardly get out of bed, was very cranky, and slept for nearly 8 hours on a drive home from school vacation (very unusual for him.) I called his doctor on Monday morning and she said to stick it out a few days. See how he did at school, and with getting up in the morning. The last two days have been problem free. He is MUCH more agreeable than ever. He is less emotional (a good thing), less cranky. He is remembering all the things he should. Overall his behavior is better. \r\nWe have tried many different medications and so far this is the most effective."'

# %%
example_text = drug_dataset["train"][0]["review"]

tokens = tokenizer(
    example_text,
    truncation=True,
    max_length=128,
    return_overflowing_tokens=True,
)

# %%
len(tokens['input_ids'])
# Out:
# 2

# %%
#tokens["input_ids"]

# %%
print(f"Number of token chunks for example 0: {len(tokens['input_ids'])}")
print("Token IDs:", tokens["input_ids"])
# Out:
# Number of token chunks for example 0: 2
# ...

# %%
batch = drug_dataset["train"][:5]["review"]  # take first 5 reviews

tokenized_batch = tokenizer(
    batch,
    truncation=True,
    max_length=128,
    return_overflowing_tokens=True,
)

print(f"Number of token chunks in batch: {len(tokenized_batch['input_ids'])}")
print(f"Number of input reviews in batch: {len(batch)}")

print("Overflow to sample mapping:", tokenized_batch.get("overflow_to_sample_mapping"))
# Out:
# Number of token chunks in batch: 8
# Number of input reviews in batch: 5
# Overflow to sample mapping: [0, 0, 1, 1, 2, 3, 3, 4]

# %%
tokenized_dataset = drug_dataset.map(
    tokenize_and_split, batched=True, remove_columns=drug_dataset["train"].column_names
)
# Out:
# ...
# Map:   0%|          | 0/46108 [00:00<?, ? examples/s]

# %%
len(tokenized_dataset["train"]), len(drug_dataset["train"])
# Out:
# (206772, 138514)

# %% [markdown]
# # Dataset Library to pandas

# %%
drug_dataset.set_format("pandas")

# %%
drug_dataset["train"][:3]
# Out:
#    patient_id    drugName      condition  \
# 0       95260  Guanfacine           adhd
# 1       92703      Lybrel  birth control
# 2      138000  Ortho Evra  birth control
#
#                                               review  rating  \
# 0  "My son is halfway through his fourth week of ...     8.0
# 1  "I used to take another oral contraceptive, wh...     5.0
# 2  "This is my first time using any form of birth...     8.0
#
#                 date  usefulCount  review_length
# 0     April 27, 2010          192            141
# 1  December 14, 2009           17            134
# 2   November 3, 2015           10             89

# %%
train_df = drug_dataset["train"][:]

# %%
frequencies = (
    train_df["condition"]
    .value_counts()
    .to_frame()
    .reset_index()
    .rename(columns={"index": "condition", "count": "frequency"})
)
frequencies.head()
# Out:
#        condition  frequency
# 0  birth control      27655
# 1     depression       8023
# 2           acne       5209
# 3        anxiety       4991
# 4           pain       4744

# %%
from datasets import Dataset

freq_dataset = Dataset.from_pandas(frequencies)
freq_dataset
# Out:
# Dataset({
#     features: ['condition', 'frequency'],
#     num_rows: 819
# })

# %%
drug_dataset.reset_format()

# %%
drug_dataset_clean=drug_dataset["train"].train_test_split(train_size=0.8, seed =42)

drug_dataset_clean["validation"]=drug_dataset_clean.pop("test")

drug_dataset_clean["test"] = drug_dataset["test"]
drug_dataset_clean
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 110811
#     })
#     validation: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 27703
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 46108
#     })
# })

# %%
drug_dataset_clean.save_to_disk("drug_reviews")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/46108 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk

drug_dataset_reloaded = load_from_disk("drug_reviews")

drug_dataset_reloaded
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 110811
#     })
#     validation: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 27703
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 46108
#     })
# })
